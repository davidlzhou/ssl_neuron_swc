# %%
# %env CUDA_DEVICE_ORDER=PCI_BUS_ID
# %env CUDA_VISIBLE_DEVICES=0
# %pylab inline
# %load_ext autoreload
# %autoreload 2
# Out:
# env: CUDA_DEVICE_ORDER=PCI_BUS_ID
# env: CUDA_VISIBLE_DEVICES=0
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
from pathlib import Path
import pickle
import pandas as pd
from tqdm import tqdm
import networkx as nx
from allensdk.core.cell_types_cache import CellTypesCache

import numpy as np

# %%
from ssl_neuron.data.data_utils import connect_graph, remove_axon, rotate_cell
from ssl_neuron.utils import neighbors_to_adjacency, plot_neuron

# %% [markdown]
# #### Load ids

# %%
cell_ids = list(np.load('all_ids.npy'))

# %% [markdown]
# #### Load Cell Types Database

# %%
ctc = CellTypesCache(manifest_file='cell_types/manifest.json')

# %% [markdown]
# #### Load table with additional information

# %%
# Download link in readme (https://github.com/marissaweis/ssl_neuron/tree/main/ssl_neuron/data).
df = pd.read_csv('41593_2019_417_MOESM5_ESM.csv', delimiter=',', decimal=".")

# %%
cl = rotate_cell(cell_ids[0], ctc.get_reconstruction(cell_ids[0]), df).compartment_list
neighbors = {}
idx2node = {}
for i, item in enumerate(cl):
    # Get node features.
    sec_type = [0, 0, 0, 0]
    sec_type[item['type'] - 1] = 1
    feat = tuple([item['x'], item['y'], item['z'], item['radius']]) + tuple(sec_type)
    idx2node[i] = feat
    
    # Get neighbors.
    neighbors[i] = set(item['children'])
    if item['parent'] != -1:
        neighbors[i].add(item['parent'])

# %%
sec_type = [0,0,0,0]
sec_type[cl[0]['type'] - 1] = 1
sec_type
# Out:
# [1, 0, 0, 0]

# %%
cl[6]
# Out:
# {'id': 6,
#  'type': 2,
#  'x': -513.5656092948152,
#  'y': 148.75124136840194,
#  'z': -18.966701784568926,
#  'radius': 0.4060955368984879,
#  'parent': 5,
#  'tree_id': 0,
#  'children': [7]}

# %% [markdown]
# #### Preprocess cells

# %%
for cell_id in tqdm(cell_ids):
    path = Path('./skeletons/', str(cell_id))
    path.mkdir(parents=True, exist_ok=True)

    morphology = ctc.get_reconstruction(cell_id) 
    
    # Rotate respecitve to pia.
    morphology = rotate_cell(cell_id, morphology, df)

    # Get soma coordinates.
    soma = morphology.soma
    soma_pos = np.array([soma['x'], soma['y'], soma['z']])
    soma_id = soma['id']

    # Process graph.
    neighbors = {}
    idx2node = {}
    for i, item in enumerate(morphology.compartment_list):
        # Get node features.
        sec_type = [0, 0, 0, 0]
        sec_type[item['type'] - 1] = 1
        feat = tuple([item['x'], item['y'], item['z'], item['radius']]) + tuple(sec_type)
        idx2node[i] = feat
        
        # Get neighbors.
        neighbors[i] = set(item['children'])
        if item['parent'] != -1:
            neighbors[i].add(item['parent'])

    features = np.array(list(idx2node.values()))
    
    assert ~np.any(np.isnan(features))
    
    # Normalize soma position to origin.
    norm_features = features.copy()
    norm_features[:, :3] = norm_features[:, :3] - soma_pos
    
    # Test if graph is connected.
    adj_matrix = neighbors_to_adjacency(neighbors, range(len(neighbors)))
    G = nx.Graph(adj_matrix)
    if nx.number_connected_components(G) > 1:
        adj_matrix, neighbors = connect_graph(adj_matrix, neighbors, features)
        
    assert len(neighbors) == len(adj_matrix)

    # Remove axons.
    neighbors, norm_features, soma_id = remove_axon(neighbors, norm_features, int(soma_id))

    assert len(neighbors) == len(norm_features)
    assert ~np.any(np.isnan(norm_features))

    np.save(Path(path, 'features'), norm_features)
    with open(Path(path, 'neighbors.pkl'), 'wb') as f:
        pickle.dump(dict(neighbors), f, pickle.HIGHEST_PROTOCOL)
# Out:
#   0%|          | 1/430 [00:04<34:24,  4.81s/it]2026-07-15 15:05:10,623 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/
allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/599475045
#  96%|█████████▌| 412/430 [18:35<00:16,  1.10it/s]2026-07-15 15:23:41,526 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/652192444
#  96%|█████████▌| 413/430 [18:36<00:13,  1.23it/s]2026-07-15 15:23:42,161 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/657210083
#  96%|█████████▋| 414/430 [18:36<00:11,  1.36it/s]2026-07-15 15:23:42,684 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/661930471
#  97%|█████████▋| 415/430 [18:39<00:19,  1.30s/it]2026-07-15 15:23:45,283 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/609847139
#  97%|█████████▋| 416/430 [18:40<00:14,  1.06s/it]2026-07-15 15:23:45,800 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/656643534
#  97%|█████████▋| 417/430 [18:40<00:12,  1.04it/s]2026-07-15 15:23:46,541 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/675965556
#  97%|█████████▋| 418/430 [18:41<00:09,  1.23it/s]2026-07-15 15:23:47,009 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/652303156
#  97%|█████████▋| 419/430 [18:41<00:08,  1.28it/s]2026-07-15 15:23:47,701 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/708729834
#  98%|█████████▊| 420/430 [18:42<00:07,  1.40it/s]2026-07-15 15:23:48,257 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/653148743
#  98%|█████████▊| 421/430 [18:43<00:06,  1.39it/s]2026-07-15 15:23:48,995 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/652307119
#  98%|█████████▊| 422/430 [18:43<00:05,  1.50it/s]2026-07-15 15:23:49,549 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/652836480
#  98%|█████████▊| 423/430 [18:44<00:04,  1.45it/s]2026-07-15 15:23:50,272 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/651482866
#  99%|█████████▊| 424/430 [18:45<00:03,  1.54it/s]2026-07-15 15:23:50,847 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/652287164
#  99%|█████████▉| 425/430 [18:45<00:03,  1.56it/s]2026-07-15 15:23:51,469 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/675964895
#  99%|█████████▉| 426/430 [18:46<00:02,  1.64it/s]2026-07-15 15:23:51,992 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/647860105
#  99%|█████████▉| 427/430 [18:46<00:01,  1.84it/s]2026-07-15 15:23:52,383 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/645065213
# 100%|█████████▉| 428/430 [18:47<00:01,  1.87it/s]2026-07-15 15:23:52,895 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/646827530
# 100%|█████████▉| 429/430 [18:47<00:00,  1.95it/s]2026-07-15 15:23:53,364 allensdk.api.api.retrieve_file_over_http INFO     Downloading URL: http://api.brain-map.org/api/v2/well_known_file_download/647469823
# 100%|██████████| 430/430 [18:48<00:00,  2.62s/it]

# %% [markdown]
# #### Visualize neuron

# %%
# Load neuronal data.
path = Path('./skeletons/', '623185845')
features = np.load(Path(path, 'features.npy'))
with open(Path(path, 'neighbors.pkl'), 'rb') as f:
    neighbors = pickle.load(f)

# %%
pickle.HIGHEST_PROTOCOL
# Out:
# 5

# %%
with open('/Users/davidzhou/Documents/GitHub/ssl_neuron/ssl_neuron/data/skeletons/623185845/neighbors.pkl', 'rb') as f:
    nb = pickle.load(f)
ft = np.load('/Users/davidzhou/Documents/GitHub/ssl_neuron/ssl_neuron/data/skeletons/623185845/features.npy')
 
ft[:4]
# Out:
# array([[ 0.        ,  0.        ,  0.        ,  7.62027863,  1.        ,
#          0.        ,  0.        ,  0.        ],
#        [-2.56612035,  6.9429454 , -4.0550173 ,  0.56677941,  0.        ,
#          0.        ,  1.        ,  0.        ],
#        [-2.89650034,  7.9551065 , -4.66204455,  0.55658158,  0.        ,
#          0.        ,  1.        ,  0.        ],
#        [-3.24689426,  9.0650295 , -5.13656797,  0.54678366,  0.        ,
#          0.        ,  1.        ,  0.        ]])

# %%
plot_neuron(neighbors, features)
